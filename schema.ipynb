# %%
import polars as pl

dict(pl.scan_ndjson("sample/part_000").collect_schema())
# Out:
# {'grants': List(Struct({'funder': String, 'funder_display_name': String, 'award_id': String})),
#  'language_id': String,
#  'corresponding_author_ids': List(String),
#  'versions': List(Null),
#  'referenced_works_count': Int64,
#  'updated_date': String,
#  'citation_normalized_percentile': Struct({'value': Float64, 'is_in_top_1_percent': Boolean, 'is_in_top_10_percent': Boolean}),
#  'keywords': List(Struct({'id': String, 'display_name': String, 'score': Float64})),
#  'id': String,
#  'doi_registration_agency': String,
#  'cited_by_count': Int64,
#  'open_access': Struct({'is_oa': Boolean, 'oa_status': String, 'oa_url': String, 'any_repository_has_fulltext': Boolean}),
#  'apc_paid': Struct({'value': Int64, 'currency': String, 'value_usd': Int64, 'provenance': String}),
#  'summary_stats': Struct({'cited_by_count': Int64, '2yr_cited_by_count': Int64}),
#  'created_date': String,
#  'countries_distinct_count': Int64,
# ...
